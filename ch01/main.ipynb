# %% [markdown]
# # 1章 - Python 入門

# %% [markdown]
# ## hungry.py

# %%
print("I'm hungry!")
# Out:
# I'm hungry!

# %% [markdown]
# ## man.py

# %%
class Man:
  def __init__(self, name):
    self.name = name
    print("Initialized!")

  def hello(self):
    print("Hello " + self.name + "!")

  def goodbye(self):
    print("Good-bye " + self.name + "!")

m = Man("David")
m.hello()
m.goodbye()
# Out:
# Initialized!
# Hello David!
# Good-bye David!

# %% [markdown]
# ## simple_graph.py

# %%
import numpy as np
import matplotlib.pyplot as plt

# データの作成
x = np.arange(0, 6, 0.1) # 0から6まで0.1刻みで生成
y = np.sin(x)

# グラフの描画
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## sin_cos_graph.py

# %%
import numpy as np
import matplotlib.pyplot as plt

# データの作成
x = np.arange(0, 6, 0.1) # 0から6まで0.1刻みで生成
y1 = np.sin(x)
y2 = np.cos(x)

# グラフの描画
plt.plot(x, y1, label="sin")
plt.plot(x, y2, linestyle = "--", label="cos")
plt.xlabel("x") # x軸のラベル
plt.ylabel("y") # y軸のラベル
plt.title('sin & cos') # タイトル
plt.legend()
plt.show()

# %% [markdown]
# ## img_show.py

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('/content/drive/MyDrive/repositories/my-zerodeep/dataset/ssbu_cloud_color2.png') # 画像の読み込み（適切なパスを設定する！）
plt.imshow(img)

plt.show()
